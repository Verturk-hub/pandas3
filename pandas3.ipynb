# %%
import pandas as pd

# %%
dictionary = { 'name': ['Hazel', 'Ali'],
'age':[38,5],
'occ': ['Data Scientist','Engineer']}

df = pd.DataFrame(dictionary)
df
# Out:
#     name  age             occ
# 0  Hazel   38  Data Scientist
# 1    Ali    5        Engineer

# %%
lists=[['Hazel', 38, 'DS'],
['Ali',5,'Engineer']]

df1 = pd.DataFrame(lists, columns=['name','age','occ'])
df1
# Out:
#     name  age       occ
# 0  Hazel   38        DS
# 1    Ali    5  Engineer

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\herturk\\OneDrive - Managed Network Solutions Inc\\Desktop'

# %%
os.chdir('c:\\Users\\herturk\\OneDrive - Managed Network Solutions Inc\\Desktop\\Training')
df2= pd.read_csv('winequality-red.csv')
df2.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df3 = df2.set_index('pH')
df3.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# pH
# 3.51            7.4              0.70         0.00             1.9      0.076
# 3.20            7.8              0.88         0.00             2.6      0.098
# 3.26            7.8              0.76         0.04             2.3      0.092
# 3.16           11.2              0.28         0.56             1.9      0.075
# 3.51            7.4              0.70         0.00             1.9      0.076
#
#       free sulfur dioxide  total sulfur dioxide  density  sulphates  alcohol  \
# pH
# 3.51                 11.0                  34.0   0.9978       0.56      9.4
# 3.20                 25.0                  67.0   0.9968       0.68      9.8
# 3.26                 15.0                  54.0   0.9970       0.65      9.8
# 3.16                 17.0                  60.0   0.9980       0.58      9.8
# 3.51                 11.0                  34.0   0.9978       0.56      9.4
#
#       quality
# pH
# ...

# %%
df4 = df3.sort_index()
df4.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# pH
# 2.74            9.2             0.520         1.00             3.4      0.610
# 2.86           14.3             0.310         0.74             1.8      0.075
# 2.87            9.2             0.755         0.18             2.2      0.148
# 2.88           12.6             0.310         0.72             2.2      0.072
# 2.88           10.0             0.690         0.11             1.4      0.084
#
#       free sulfur dioxide  total sulfur dioxide  density  sulphates  alcohol  \
# pH
# 2.74                 32.0                  69.0  0.99960       2.00      9.4
# 2.86                  6.0                  15.0  1.00080       0.79      8.4
# 2.87                 10.0                 103.0  0.99690       1.36     10.2
# 2.88                  6.0                  29.0  0.99870       0.82      9.8
# 2.88                  8.0                  24.0  0.99578       0.47      9.7
#
#       quality
# pH
# ...

# %%
df5 = df4.sort_values(by=['alcohol','density'])
df5.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# pH
# 3.16           10.4              0.61         0.49             2.1      0.200
# 2.86           14.3              0.31         0.74             1.8      0.075
# 3.15           10.0              0.38         0.38             1.6      0.169
# 3.32            7.9              0.24         0.40             1.6      0.056
# 3.34            8.2              0.42         0.49             2.6      0.084
#
#       free sulfur dioxide  total sulfur dioxide  density  sulphates  alcohol  \
# pH
# 3.16                  5.0                  16.0  0.99940       0.63      8.4
# 2.86                  6.0                  15.0  1.00080       0.79      8.4
# 3.15                 27.0                  90.0  0.99914       0.65      8.5
# 3.32                 11.0                  25.0  0.99670       0.87      8.7
# 3.34                 32.0                  55.0  0.99880       0.75      8.7
#
#       quality
# pH
# ...

# %%
df6 = df4.reset_index()
df6.head(3)
# Out:
#      pH  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  2.74            9.2             0.520         1.00             3.4
# 1  2.86           14.3             0.310         0.74             1.8
# 2  2.87            9.2             0.755         0.18             2.2
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density  sulphates  \
# 0      0.610                 32.0                  69.0   0.9996       2.00
# 1      0.075                  6.0                  15.0   1.0008       0.79
# 2      0.148                 10.0                 103.0   0.9969       1.36
#
#    alcohol  quality
# 0      9.4        4
# 1      8.4        6
# 2     10.2        6

# %%
x = df6['quality']
print(x, end='')
# Out:
# 0       4
# 1       6
# 2       6
# 3       8
# 4       5
#        ..
# 1594    6
# 1595    4
# 1596    6
# 1597    6
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
df6.iloc[:, 11]
# Out:
# 0       4
# 1       6
# 2       6
# 3       8
# 4       5
#        ..
# 1594    6
# 1595    4
# 1596    6
# 1597    6
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
df6.loc[:,'quality']
# Out:
# 0       4
# 1       6
# 2       6
# 3       8
# 4       5
#        ..
# 1594    6
# 1595    4
# 1596    6
# 1597    6
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
df6.iloc[[0,1],:]
# Out:
#      pH  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  2.74            9.2              0.52         1.00             3.4
# 1  2.86           14.3              0.31         0.74             1.8
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density  sulphates  \
# 0      0.610                 32.0                  69.0   0.9996       2.00
# 1      0.075                  6.0                  15.0   1.0008       0.79
#
#    alcohol  quality
# 0      9.4        4
# 1      8.4        6

# %%
df7 = df5.loc[df5.quality>7]
df7.head(7)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# pH
# 2.88           12.6              0.31         0.72             2.2      0.072
# 3.23            7.2              0.33         0.33             1.7      0.061
# 3.15           10.7              0.35         0.53             2.6      0.070
# 3.15           10.7              0.35         0.53             2.6      0.070
# 3.23            7.2              0.38         0.31             2.0      0.056
# 3.24            7.4              0.36         0.30             1.8      0.074
# 3.35            8.6              0.42         0.39             1.8      0.068
#
#       free sulfur dioxide  total sulfur dioxide  density  sulphates  alcohol  \
# pH
# 2.88                  6.0                  29.0  0.99870       0.82      9.8
# 3.23                  3.0                  13.0  0.99600       1.10     10.0
# 3.15                  5.0                  16.0  0.99720       0.65     11.0
# ...

# %%
df5.groupby('total sulfur dioxide')['quality'].mean()
# Out:
# total sulfur dioxide
# 6.0      5.333333
# 7.0      5.500000
# 8.0      5.714286
# 9.0      5.571429
# 10.0     6.370370
#            ...
# 155.0    5.000000
# 160.0    6.000000
# 165.0    6.000000
# 278.0    7.000000
# 289.0    7.000000
# Name: quality, Length: 144, dtype: float64

# %%
df5.fillna(0)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# pH
# 3.16           10.4              0.61         0.49             2.1      0.200
# 2.86           14.3              0.31         0.74             1.8      0.075
# 3.15           10.0              0.38         0.38             1.6      0.169
# 3.32            7.9              0.24         0.40             1.6      0.056
# 3.34            8.2              0.42         0.49             2.6      0.084
# ...             ...               ...          ...             ...        ...
# 3.68            5.2              0.34         0.00             1.8      0.050
# 3.68            5.2              0.34         0.00             1.8      0.050
# 3.72            5.0              0.42         0.24             2.0      0.060
# 3.32            8.8              0.46         0.45             2.6      0.065
# 2.98           15.9              0.36         0.65             7.5      0.096
#
# ...

# %%
df8 = df4.isnull().count()
df8
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %%
df5['quality'] = df5['quality'].apply(lambda x:x>5)
df5
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# pH
# 3.16           10.4              0.61         0.49             2.1      0.200
# 2.86           14.3              0.31         0.74             1.8      0.075
# 3.15           10.0              0.38         0.38             1.6      0.169
# 3.32            7.9              0.24         0.40             1.6      0.056
# 3.34            8.2              0.42         0.49             2.6      0.084
# ...             ...               ...          ...             ...        ...
# 3.68            5.2              0.34         0.00             1.8      0.050
# 3.68            5.2              0.34         0.00             1.8      0.050
# 3.72            5.0              0.42         0.24             2.0      0.060
# 3.32            8.8              0.46         0.45             2.6      0.065
# 2.98           15.9              0.36         0.65             7.5      0.096
#
# ...

# %%
df9 = pd.merge(df3, df5, how='inner', on = 'alcohol')
df9
# Out:
#        fixed acidity_x  volatile acidity_x  citric acid_x  residual sugar_x  \
# 0                  7.4               0.700           0.00               1.9
# 1                  7.4               0.700           0.00               1.9
# 2                  7.4               0.700           0.00               1.9
# 3                  7.4               0.700           0.00               1.9
# 4                  7.4               0.700           0.00               1.9
# ...                ...                 ...            ...               ...
# 89256              6.7               0.760           0.02               1.8
# 89257              6.9               0.840           0.21               4.1
# 89258              6.9               0.840           0.21               4.1
# 89259              6.9               0.480           0.20               1.9
# 89260              6.7               0.855           0.02               1.9
#
# ...

# %%
df9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89261 entries, 0 to 89260
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   fixed acidity_x         89261 non-null  float64
#  1   volatile acidity_x      89261 non-null  float64
#  2   citric acid_x           89261 non-null  float64
#  3   residual sugar_x        89261 non-null  float64
#  4   chlorides_x             89261 non-null  float64
#  5   free sulfur dioxide_x   89261 non-null  float64
#  6   total sulfur dioxide_x  89261 non-null  float64
#  7   density_x               89261 non-null  float64
#  8   sulphates_x             89261 non-null  float64
#  9   alcohol                 89261 non-null  float64
#  10  quality_x               89261 non-null  int64
#  11  fixed acidity_y         89261 non-null  float64
#  12  volatile acidity_y      89261 non-null  float64
#  13  citric acid_y           89261 non-null  float64
# ...

# %%
df9.describe()
# Out:
#        fixed acidity_x  volatile acidity_x  citric acid_x  residual sugar_x  \
# count     89261.000000        89261.000000   89261.000000      89261.000000
# mean          8.309297            0.540431       0.257798          2.470125
# std           1.600238            0.172497       0.186570          1.287618
# min           4.600000            0.120000       0.000000          0.900000
# 25%           7.200000            0.410000       0.100000          1.900000
# 50%           7.900000            0.540000       0.240000          2.200000
# 75%           9.100000            0.640000       0.400000          2.600000
# max          15.900000            1.580000       1.000000         15.500000
#
#         chlorides_x  free sulfur dioxide_x  total sulfur dioxide_x  \
# count  89261.000000           89261.000000            89261.000000
# mean       0.090843              16.167761               50.670416
# std        0.051876              10.503501               34.273512
# ...
